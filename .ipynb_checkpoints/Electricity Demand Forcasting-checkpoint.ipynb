# %% [markdown]
# **PROJECT  --- ELECTRICITY DEMAND FORCASTING**

# %%
#importing lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import random

# %%
data=pd.read_csv('ElectricityData.csv')

# %%
data
# Out:
#        Timestamp  hour  dayofweek  month    year  dayofyear  Temperature  \
# 0      01-Jan-20   0.0        2.0    1.0  2020.0        1.0     3.000000
# 1      01-Jan-20   1.0        2.0    1.0  2020.0        1.0     3.000000
# 2      01-Jan-20   2.0        2.0    1.0  2020.0        1.0     4.244482
# 3      01-Jan-20   3.0        2.0    1.0  2020.0        1.0     3.000000
# 4      01-Jan-20   4.0        2.0    1.0  2020.0        1.0     3.881208
# ...          ...   ...        ...    ...     ...        ...          ...
# 43843  31-Dec-24  19.0        1.0   12.0  2024.0      366.0     3.956838
# 43844  31-Dec-24  20.0        1.0   12.0  2024.0      366.0     3.118824
# 43845  31-Dec-24  21.0        1.0   12.0  2024.0      366.0     3.000000
# 43846  31-Dec-24  22.0        1.0   12.0  2024.0      366.0     3.000000
# 43847  31-Dec-24  23.0        1.0   12.0  2024.0      366.0     6.037472
#
#         Humidity       Demand
# 0      61.288951  2457.119872
# 1      52.873702  2269.904712
# 2      36.341783  2215.640403
# 3      72.629378  2174.232413
# 4      90.582444  2472.453006
# ...          ...          ...
# 43843  43.287161  4689.693109
# 43844  51.705756  4331.249224
# 43845  40.565916  4015.979957
# 43846  51.998107  3353.241682
# 43847  59.931925  3219.023339
#
# [43848 rows x 9 columns]

# %%
# Data exploration
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43848 entries, 0 to 43847
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Timestamp    43848 non-null  object
#  1   hour         43837 non-null  float64
#  2   dayofweek    43839 non-null  float64
#  3   month        43840 non-null  float64
#  4   year         43843 non-null  float64
#  5   dayofyear    43843 non-null  float64
#  6   Temperature  43841 non-null  float64
#  7   Humidity     43838 non-null  float64
#  8   Demand       43841 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 3.0+ MB

# %%
#convert  the col datatype to datatime format

data['Timestamp'] = pd.to_datetime(data['Timestamp'], format='%d-%b-%y')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43848 entries, 0 to 43847
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Timestamp    43848 non-null  datetime64[ns]
#  1   hour         43837 non-null  float64
#  2   dayofweek    43839 non-null  float64
#  3   month        43840 non-null  float64
#  4   year         43843 non-null  float64
#  5   dayofyear    43843 non-null  float64
#  6   Temperature  43841 non-null  float64
#  7   Humidity     43838 non-null  float64
#  8   Demand       43841 non-null  float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 3.0 MB

# %%
data
# Out:
#        Timestamp  hour  dayofweek  month    year  dayofyear  Temperature  \
# 0     2020-01-01   0.0        2.0    1.0  2020.0        1.0     3.000000
# 1     2020-01-01   1.0        2.0    1.0  2020.0        1.0     3.000000
# 2     2020-01-01   2.0        2.0    1.0  2020.0        1.0     4.244482
# 3     2020-01-01   3.0        2.0    1.0  2020.0        1.0     3.000000
# 4     2020-01-01   4.0        2.0    1.0  2020.0        1.0     3.881208
# ...          ...   ...        ...    ...     ...        ...          ...
# 43843 2024-12-31  19.0        1.0   12.0  2024.0      366.0     3.956838
# 43844 2024-12-31  20.0        1.0   12.0  2024.0      366.0     3.118824
# 43845 2024-12-31  21.0        1.0   12.0  2024.0      366.0     3.000000
# 43846 2024-12-31  22.0        1.0   12.0  2024.0      366.0     3.000000
# 43847 2024-12-31  23.0        1.0   12.0  2024.0      366.0     6.037472
#
#         Humidity       Demand
# 0      61.288951  2457.119872
# 1      52.873702  2269.904712
# 2      36.341783  2215.640403
# 3      72.629378  2174.232413
# 4      90.582444  2472.453006
# ...          ...          ...
# 43843  43.287161  4689.693109
# 43844  51.705756  4331.249224
# 43845  40.565916  4015.979957
# 43846  51.998107  3353.241682
# 43847  59.931925  3219.023339
#
# [43848 rows x 9 columns]

# %%
# set this datetime as index of our dataframe
data=data.set_index('Timestamp')

# %%
data
# Out:
#             hour  dayofweek  month    year  dayofyear  Temperature   Humidity  \
# Timestamp
# 2020-01-01   0.0        2.0    1.0  2020.0        1.0     3.000000  61.288951
# 2020-01-01   1.0        2.0    1.0  2020.0        1.0     3.000000  52.873702
# 2020-01-01   2.0        2.0    1.0  2020.0        1.0     4.244482  36.341783
# 2020-01-01   3.0        2.0    1.0  2020.0        1.0     3.000000  72.629378
# 2020-01-01   4.0        2.0    1.0  2020.0        1.0     3.881208  90.582444
# ...          ...        ...    ...     ...        ...          ...        ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0     3.956838  43.287161
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0     3.118824  51.705756
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0     3.000000  40.565916
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0     3.000000  51.998107
# 2024-12-31  23.0        1.0   12.0  2024.0      366.0     6.037472  59.931925
#
#                  Demand
# Timestamp
# 2020-01-01  2457.119872
# 2020-01-01  2269.904712
# 2020-01-01  2215.640403
# 2020-01-01  2174.232413
# 2020-01-01  2472.453006
# ...                 ...
# 2024-12-31  4689.693109
# 2024-12-31  4331.249224
# 2024-12-31  4015.979957
# 2024-12-31  3353.241682
# 2024-12-31  3219.023339
#
# [43848 rows x 8 columns]

# %%
#use describe func to check summary stats
data[['Temperature','Humidity','Demand']].describe()
# Out:
#         Temperature      Humidity        Demand
# count  43841.000000  43838.000000  43841.000000
# mean      25.067788     59.903007   5000.790976
# std       12.821725     18.342604   1412.527409
# min        3.000000     20.000000   1611.954020
# 25%       15.210186     46.241224   4015.668472
# 50%       25.003212     59.986720   5013.053367
# 75%       34.740971     73.796820   6000.803082
# max       50.000000     95.000000  11910.705100

# %%
#DATA CLEANING
#check for missing values
data.isnull().sum()
# Out:
# hour           11
# dayofweek       9
# month           8
# year            5
# dayofyear       5
# Temperature     7
# Humidity       10
# Demand          7
# dtype: int64

# %%
#to show records that contain  any null val/missing val
data[data.isna().any(axis=1)]
# Out:
#             hour  dayofweek  month    year  dayofyear  Temperature   Humidity  \
# Timestamp
# 2020-04-30   NaN        3.0    4.0  2020.0      121.0    21.820261  41.353675
# 2020-07-21   NaN        1.0    7.0  2020.0      203.0    36.555833  62.779665
# 2021-02-20   NaN        NaN    NaN     NaN        NaN          NaN        NaN
# 2021-02-20   NaN        NaN    NaN     NaN        NaN          NaN        NaN
# 2021-02-20   NaN        NaN    NaN     NaN        NaN          NaN        NaN
# 2021-02-20   NaN        NaN    NaN     NaN        NaN          NaN        NaN
# 2021-02-20   NaN        NaN    NaN   NaN        NaN          NaN       NaN
# 2021-02-20   NaN        NaN    NaN   NaN        NaN          NaN       NaN
# 2021-02-20   NaN        NaN    NaN   NaN        NaN          NaN       NaN
# 2021-02-20   NaN        NaN    NaN   NaN        NaN          NaN       NaN
#
#             Demand
# Timestamp
# 2021-02-20     NaN
# 2021-02-20     NaN
# 2021-02-20     NaN
# 2021-02-20     NaN

# %%
# Drop all those records containing all missing values
data=data.dropna(how='all')

# %%
data
# Out:
#             hour  dayofweek  month    year  dayofyear  Temperature   Humidity  \
# Timestamp
# 2020-01-01   0.0        2.0    1.0  2020.0        1.0     3.000000  61.288951
# 2020-01-01   1.0        2.0    1.0  2020.0        1.0     3.000000  52.873702
# 2020-01-01   2.0        2.0    1.0  2020.0        1.0     4.244482  36.341783
# 2020-01-01   3.0        2.0    1.0  2020.0        1.0     3.000000  72.629378
# 2020-01-01   4.0        2.0    1.0  2020.0        1.0     3.881208  90.582444
# ...          ...        ...    ...     ...        ...          ...        ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0     3.956838  43.287161
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0     3.118824  51.705756
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0     3.000000  40.565916
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0     3.000000  51.998107
# 2024-12-31  23.0        1.0   12.0  2024.0      366.0     6.037472  59.931925
#
#                  Demand
# Timestamp
# 2020-01-01  2457.119872
# 2020-01-01  2269.904712
# 2020-01-01  2215.640403
# 2020-01-01  2174.232413
# 2020-01-01  2472.453006
# ...                 ...
# 2024-12-31  4689.693109
# 2024-12-31  4331.249224
# 2024-12-31  4015.979957
# 2024-12-31  3353.241682
# 2024-12-31  3219.023339
#
# [43844 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# hour           7
# dayofweek      5
# month          4
# year           1
# dayofyear      1
# Temperature    3
# Humidity       6
# Demand         3
# dtype: int64

# %%
# to fill the null values we have in some columns we will use bfill,ffill
# data[['hour','dayofweek','month','year','dayofyear']] = data[['hour','dayofweek','month','year','dayofyear']].ffill

data.loc[:, ['hour','dayofweek','month','year','dayofyear']] = (
    data.loc[:, ['hour','dayofweek','month','year','dayofyear']].ffill()
)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15276\1697033142.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:, ['hour','dayofweek','month','year','dayofyear']] = (

# %%
data.loc[:, ['Temperature','Humidity']] = data.loc[:, ['Temperature','Humidity']].bfill()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15276\3652072529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:, ['Temperature','Humidity']] = data.loc[:, ['Temperature','Humidity']].bfill()

# %%
data.loc[:, 'Demand'] = data['Demand'].interpolate(method='time')

# %%
data.isnull().sum()
# Out:
# hour           0
# dayofweek      0
# month          0
# year           0
# dayofyear      0
# Temperature    0
# Humidity       0
# Demand         0
# dtype: int64

# %%
data.shape
# Out:
# (43844, 8)

# %%
#Feature engineering

#Create quarter column in dataset

data.insert(5,'quarter',data.index.quarter)

# %%
data
# Out:
#             hour  dayofweek  month    year  dayofyear  quarter  Temperature  \
# Timestamp
# 2020-01-01   0.0        2.0    1.0  2020.0        1.0        1     3.000000
# 2020-01-01   1.0        2.0    1.0  2020.0        1.0        1     3.000000
# 2020-01-01   2.0        2.0    1.0  2020.0        1.0        1     4.244482
# 2020-01-01   3.0        2.0    1.0  2020.0        1.0        1     3.000000
# 2020-01-01   4.0        2.0    1.0  2020.0        1.0        1     3.881208
# ...          ...        ...    ...     ...        ...      ...          ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0        4     3.956838
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0        4     3.118824
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0        4     3.000000
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0        4     3.000000
# 2024-12-31  23.0        1.0   12.0  2024.0      366.0        4     6.037472
#
#              Humidity       Demand
# Timestamp
# 2020-01-01  61.288951  2457.119872
# 2020-01-01  52.873702  2269.904712
# 2020-01-01  36.341783  2215.640403
# 2020-01-01  72.629378  2174.232413
# 2020-01-01  90.582444  2472.453006
# ...               ...          ...
# 2024-12-31  43.287161  4689.693109
# 2024-12-31  51.705756  4331.249224
# 2024-12-31  40.565916  4015.979957
# 2024-12-31  51.998107  3353.241682
# 2024-12-31  59.931925  3219.023339
#
# [43844 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43844 entries, 2020-01-01 to 2024-12-31
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour         43844 non-null  float64
#  1   dayofweek    43844 non-null  float64
#  2   month        43844 non-null  float64
#  3   year         43844 non-null  float64
#  4   dayofyear    43844 non-null  float64
#  5   quarter      43844 non-null  int32
#  6   Temperature  43844 non-null  float64
#  7   Humidity     43844 non-null  float64
#  8   Demand       43844 non-null  float64
# dtypes: float64(8), int32(1)
# memory usage: 3.2 MB

# %%
data.loc[:,['hour','dayofweek','month','year','dayofyear']]=data[['hour','dayofweek','month','year','dayofyear']].astype(int)

# %%
data
# Out:
#             hour  dayofweek  month    year  dayofyear  quarter  Temperature  \
# Timestamp
# 2020-01-01   0.0        2.0    1.0  2020.0        1.0        1     3.000000
# 2020-01-01   1.0        2.0    1.0  2020.0        1.0        1     3.000000
# 2020-01-01   2.0        2.0    1.0  2020.0        1.0        1     4.244482
# 2020-01-01   3.0        2.0    1.0  2020.0        1.0        1     3.000000
# 2020-01-01   4.0        2.0    1.0  2020.0        1.0        1     3.881208
# ...          ...        ...    ...     ...        ...      ...          ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0        4     3.956838
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0        4     3.118824
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0        4     3.000000
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0        4     3.000000
# 2024-12-31  23.0        1.0   12.0  2024.0      366.0        4     6.037472
#
#              Humidity       Demand
# Timestamp
# 2020-01-01  61.288951  2457.119872
# 2020-01-01  52.873702  2269.904712
# 2020-01-01  36.341783  2215.640403
# 2020-01-01  72.629378  2174.232413
# 2020-01-01  90.582444  2472.453006
# ...               ...          ...
# 2024-12-31  43.287161  4689.693109
# 2024-12-31  51.705756  4331.249224
# 2024-12-31  40.565916  4015.979957
# 2024-12-31  51.998107  3353.241682
# 2024-12-31  59.931925  3219.023339
#
# [43844 rows x 9 columns]

# %%
# Create week of the year
data.insert(5, 'weekofyear', data.index.isocalendar().week.astype(int))

# %%
data
# Out:
#             hour  dayofweek  month    year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-01   0.0        2.0    1.0  2020.0        1.0           1        1
# 2020-01-01
# 2020-01-04           1     3.000000  56.398199  1880.418696
# 2020-01-04           1     4.474526  60.603500  2005.823854
# 2020-01-04           1     7.738184  65.808825  2203.720413
# ...                ...          ...        ...          ...
# 2024-12-29           1     7.077721  46.341323  4304.049396
# 2024-12-29           1     3.000000  69.641621  4146.583958
# 2024-12-29           1     3.723222  46.751731  3366.641206
# 2024-12-29           1     3.000000  70.021729  2929.747277
# 2024-12-29           1     3.000000  52.836009  2668.369837
#
# [12524 rows x 11 columns]

# %%
# to check if there is a public holiday or not
# import Holidays package
# !pip install holidays
# Out:
# Requirement already satisfied: holidays in c:\users\hp\anaconda3\lib\site-packages (0.90)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from holidays) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from python-dateutil<3,>=2.9.0.post0->holidays) (1.17.0)
# [notice] A new release of pip is available: 25.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import holidays

# %%
# specify the country
holidays.IN(years=data.year)
# Out:
# {datetime.date(2020, 1, 26): 'Republic Day', datetime.date(2020, 8, 15): 'Independence Day', datetime.date(2020, 10, 2): 'Gandhi Jayanti', datetime.date(2020, 5, 7): 'Buddha Purnima', datetime.date(2020, 11, 14): 'Diwali', datetime.date(2020, 8, 12): 'Janmashtami', datetime.date(2020, 10, 25): 'Dussehra', datetime.date(2020, 4, 6): 'Mahavir Jayanti', datetime.date(2020, 2, 21): 'Maha Shivaratri', datetime.date(2020, 11, 30): 'Guru Nanak Jayanti', datetime.date(2020, 8, 30): 'Muharram', datetime.date(2020, 10, 30): 'Milad-un-Nabi', datetime.date(2020, 5, 25): 'Id-ul-Fitr', datetime.date(2020, 8, 1): 'Bakrid', datetime.date(2020, 4, 10): 'Good Friday', datetime.date(2020, 12, 25): 'Christmas', datetime.date(2021, 1, 26): 'Republic Day', datetime.date(2021, 8, 15): 'Independence Day', datetime.date(2021, 10, 2): 'Gandhi Jayanti', datetime.date(2021, 5, 26): 'Buddha Purnima', datetime.date(2021, 11, 4): 'Diwali', datetime.date(2021, 8, 30): 'Janmashtami', datetime.date(2021, 10, 15): 'Dussehra', datetime.date(2021, 4, 25): 'Mahavir Jayanti', datetime.date(2021, 3, 11): 'Maha Shivaratri', datetime.date(2021, 11, 19): 'Guru Nanak Jayanti', datetime.date(2021, 8, 20): 'Muharram', datetime.date(2021, 10, 19): 'Milad-un-Nabi', datetime.date(2021, 5, 14): 'Id-ul-Fitr', datetime.date(2021, 7, 21): 'Bakrid', datetime.date(2021, 4, 2): 'Good Friday', datetime.date(2021, 12, 25): 'Christmas', datetime.date(2022, 1, 26): 'Republic Day', datetime.date(2022, 8, 15): 'Independence Day', datetime.date(2022, 10, 2): 'Gandhi Jayanti', datetime.date(2022, 5, 16): 'Buddha Purnima', datetime.date(2022, 10, 24): 'Diwali', datetime.date(2022, 8, 19): 'Janmashtami', datetime.date(2022, 10, 5): 'Dussehra', datetime.date(2022, 4, 14): 'Mahavir Jayanti', datetime.date(2022, 3, 1): 'Maha Shivaratri', datetime.date(2022, 11, 8): 'Guru Nanak Jayanti', datetime.date(2022, 8, 9): 'Muharram', datetime.date(2022, 10, 9): 'Milad-un-Nabi', datetime.date(2022, 5, 3): 'Id-ul-Fitr', datetime.date(2022, 7, 10): 'Bakrid', datetime.date(2022, 4, 15): 'Good Friday', datetime.date(2022, 12, 25): 'Christmas', datetime.date(2023, 1, 26): 'Republic Day', datetime.date(2023, 8, 15): 'Independence Day', datetime.date(2023, 10, 2): 'Gandhi Jayanti', datetime.date(2023, 5, 5): 'Buddha Purnima', datetime.date(2023, 11, 12): 'Diwali', datetime.date(2023, 9, 7): 'Janmashtami', datetime.date(2023, 10, 24): 'Dussehra', datetime.date(2023, 4, 4): 'Mahavir Jayanti', datetime.date(2023, 2, 18): 'Maha Shivaratri', datetime.date(2023, 11, 27): 'Guru Nanak Jayanti', datetime.date(2023, 7, 29): 'Muharram', datetime.date(2023, 9, 28): 'Milad-un-Nabi', datetime.date(2023, 4, 22): 'Id-ul-Fitr', datetime.date(2023, 6, 29): 'Bakrid', datetime.date(2023, 4, 7): 'Good Friday', datetime.date(2023, 12, 25): 'Christmas', datetime.date(2024, 1, 26): 'Republic Day', datetime.date(2024, 8, 15): 'Independence Day', datetime.date(2024, 10, 2): 'Gandhi Jayanti', datetime.date(2024, 5, 23): 'Buddha Purnima', datetime.date(2024, 10, 31): 'Diwali', datetime.date(2024, 8, 26): 'Janmashtami', datetime.date(2024, 10, 12): 'Dussehra', datetime.date(2024, 4, 21): 'Mahavir Jayanti', datetime.date(2024, 3, 8): 'Maha Shivaratri', datetime.date(2024, 11, 15): 'Guru Nanak Jayanti', datetime.date(2024, 7, 17): 'Muharram', datetime.date(2024, 9, 16): 'Milad-un-Nabi', datetime.date(2024, 4, 11): 'Id-ul-Fitr', datetime.date(2024, 6, 17): 'Bakrid', datetime.date(2024, 3, 29): 'Good Friday', datetime.date(2024, 12, 25): 'Christmas'}

# %%
data.loc[:,'Holidays']=holidays.IN(years=data.year)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15276\2868450264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:,'Holidays']=holidays.IN(years=data.year)

# %%
data
# Out:
#             hour  dayofweek  month    year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-01   0.0        2.0    1.0  2020.0        1.0           1        1
# 2020-01-01   1.0        2.0    1.0  2020.0        1.0           1        1
# 2020-01-01   2.0        2.0    1.0  2020.0        1.0           1        1
# 2020-01-01   3.0        2.0    1.0  2020.0        1.0           1        1
# 2020-01-01   4.0        2.0    1.0  2020.0        1.0           1        1
# ...          ...        ...    ...     ...        ...         ...      ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  23.0        1.0   12.0  2024.0      366.0           1        4
#
#             is_weekend  Temperature   Humidity       Demand Holidays
# Timestamp
# 2020-01-01           0     3.000000  61.288951  2457.119872      NaN
# 2020-01-01           0     3.000000  52.873702  2269.904712      NaN
# 2020-01-01           0     4.244482  36.341783  2215.640403      NaN
# 2020-01-01           0     3.000000  72.629378  2174.232413      NaN
# 2020-01-01           0     3.881208  90.582444  2472.453006      NaN
# ...                ...          ...        ...          ...      ...
# 2024-12-31           0     3.956838  43.287161  4689.693109      NaN
# 2024-12-31           0     3.118824  51.705756  4331.249224      NaN
# 2024-12-31           0     3.000000  40.565916  4015.979957      NaN
# 2024-12-31           0     3.000000  51.998107  3353.241682      NaN
# 2024-12-31           0     6.037472  59.931925  3219.023339      NaN
#
# [43844 rows x 12 columns]

# %%
data=data.drop('Holidays',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 data=data.drop('Holidays',axis=1)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)
#    5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)
#    5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Holidays'] not found in axis"

# %%
data

# %%
# lagged features --- past values of a time series data
# use ---past demand values are strong predictors, they can be used as input  to predict future values

# %%
# demand from the same hour yesterday , same hour last week
data['demand_lag_24hrs']=data['Demand'].shift(24)

# %%
data

# %%
data.head(50)

# %%
data['Demand_lag_168hrs'] = data['Demand'].shift(168)    #24*7=168hrs

# %%
data.head(50)

# %%
data.iloc[160:200]
# Out:
#             hour  dayofweek  month    year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-07  16.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-07  17.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-07  18.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-07  19.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-07  20.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-07  21.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-07  22.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-07  23.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-08   0.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   1.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   2.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   3.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   4.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   5.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   6.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   7.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   8.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   9.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  10.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  11.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  12.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  13.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  14.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  15.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  16.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  17.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  18.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  19.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  20.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  21.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  22.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08  23.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-09   0.0        3.0    1.0  2020.0        9.0           2        1
# 2020-01-09   1.0        3.0    1.0  2020.0        9.0           2        1
# 2020-01-09   2.0        3.0    1.0  2020.0        9.0           2        1
# 2020-01-09   3.0        3.0    1.0  2020.0        9.0           2        1
# 2020-01-09   4.0        3.0    1.0  2020.0        9.0           2        1
# 2020-01-09   5.0        3.0    1.0  2020.0        9.0           2        1
# 2020-01-09   6.0        3.0    1.0  2020.0        9.0           2        1
# 2020-01-09   7.0        3.0    1.0  2020.0        9.0           2        1
#
#             is_weekend  Temperature   Humidity       Demand
# Timestamp
# 2020-01-07           0    14.016616  37.637752  4587.785143
# 2020-01-07           0     6.736632  54.734906  4833.704288
# 2020-01-07           0    17.782435  49.297649  5400.257796
# 2020-01-07           0     3.000000  37.696671  4424.534926
# 2020-01-07           0     7.116704  46.152197  4279.454320
# 2020-01-08                 3737.261108                 973.864974
# ...                                ...                        ...
# 2024-12-31                 3939.391474                 973.246610
# 2024-12-31                 3937.353242                 972.057461
# 2024-12-31                 3938.303367                 972.055830
# 2024-12-31                 3937.924562                 972.272618
# 2024-12-31                 3936.594579                 973.106891
#
# [43677 rows x 15 columns]

# %%
#Visualization
# plot raw demand over time
data['Demand'].plot(figsize=(15,6),title="Electricity Demand Over Time")
plt.xlabel("Year")
plt.ylabel("Demand(in MW)")
plt.show()

# %%
# Visualize demand by hour of day, using boxplot
plt.figure(figsize=(12,6))
sns.boxplot(data=data, x='hour', y='Demand', palette='Set3')
plt.title("Demand By Hour Of The Day")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15276\2594320652.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='hour', y='Demand', palette='Set3')

# %%
# Visualize demand by month, using boxplot

plt.figure(figsize=(10,6))
sns.boxplot(data = data, x = 'month', y = 'Demand',palette="coolwarm")
plt.title("Demand by Month")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15276\3308786181.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = data, x = 'month', y = 'Demand',palette="coolwarm")

# %%
# Scatter plot of Demand vs. Temperature
plt.figure(figsize=(10,6))
sns.scatterplot(data=data, x='Temperature', y='Demand', hue='hour', alpha=0.5, palette='Set2')
plt.title("Demand vs Temperature (colored by hour)")
plt.show()

# %%
data.corr()
# Out:
#                                 hour  dayofweek     month      year  \
# hour                        1.000000  -0.000153  0.000119  0.000047
# dayofweek                  -0.000153   1.000000  0.001112 -0.001077
# month                       0.000119   0.001112  1.000000 -0.008813
# year                        0.000047  -0.001077 -0.008813  1.000000
# dayofyear                   0.000107   0.001113  0.996483 -0.009351
# weekofyear                  0.000115   0.000243  0.971870 -0.020108
# quarter                     0.000133   0.002613  0.971289 -0.007436
# is_weekend                 -0.000233   0.790558 -0.001200  0.000985
# Temperature                 0.051881  -0.000958 -0.013947 -0.005058
# Humidity                   -0.293478  -0.002222  0.597461 -0.000696
# Demand                      0.396037  -0.127220  0.030473  0.046588
# demand_rolling_mean_24hrs   0.000209  -0.096544  0.055680  0.074903
# demand_rolling_std_24hrs    0.006937  -0.038889 -0.009308 -0.000502
# demand_rolling_mean_168hrs  0.000175   0.000021  0.096048  0.077481
# demand_rolling_std_168hrs  -0.000017   0.000317  0.032398  0.005474
#
#                             dayofyear  weekofyear   quarter  is_weekend  \
# hour                         0.000107    0.000115  0.000133   -0.000233
# dayofweek                    0.001113    0.000243  0.002613    0.790558
# month                        0.996483    0.971870  0.971289   -0.001200
# year                        -0.009351   -0.020108 -0.007436    0.000985
# dayofyear                    1.000000    0.973511  0.968175   -0.001014
# weekofyear                   0.973511    1.000000  0.947415    0.000260
# quarter                      0.968175    0.947415  1.000000    0.001151
# is_weekend                  -0.001014    0.000260  0.001151    1.000000
# Temperature                 -0.016865   -0.025609 -0.011250   -0.001041
# Humidity                     0.596759    0.596428  0.614180   -0.001296
# Demand                       0.028270    0.021432  0.033071   -0.160298
# demand_rolling_mean_24hrs    0.052151    0.040577  0.059984   -0.162655
# demand_rolling_std_24hrs    -0.012277   -0.023199 -0.004329   -0.144232
# demand_rolling_mean_168hrs   0.092593    0.080718  0.100711    0.000167
# demand_rolling_std_168hrs    0.027435    0.014178  0.034645    0.000162
#
#                             Temperature  Humidity    Demand  \
# hour                           0.051881 -0.293478  0.396037
# dayofweek                     -0.000958 -0.002222 -0.127220
# month                         -0.013947  0.597461  0.030473
# year                          -0.005058 -0.000696  0.046588
# dayofyear                     -0.016865  0.596759  0.028270
# weekofyear                    -0.025609  0.596428  0.021432
# quarter                       -0.011250  0.614180  0.033071
# is_weekend                    -0.001041 -0.001296 -0.160298
# Temperature                    1.000000  0.001429  0.828235
# Humidity                       0.001429  1.000000 -0.066229
# Demand                         0.828235 -0.066229  1.000000
# demand_rolling_mean_24hrs      0.772270  0.069126  0.614704
# demand_rolling_std_24hrs       0.568859  0.002245  0.478369
# demand_rolling_mean_168hrs     0.789095  0.108388  0.600062
# demand_rolling_std_168hrs      0.738544  0.042249  0.572373
#
#                             demand_rolling_mean_24hrs  \
# hour                                         0.000209
# dayofweek                                   -0.096544
# month                                        0.055680
# year                                         0.074903
# dayofyear                                    0.052151
# weekofyear                                   0.040577
# quarter                                      0.059984
# is_weekend                                  -0.162655
# Temperature                                  0.772270
# Humidity                                     0.069126
# Demand                                       0.614704
# demand_rolling_mean_24hrs                    1.000000
# demand_rolling_std_24hrs                     0.810988
# demand_rolling_mean_168hrs                   0.968750
# demand_rolling_std_168hrs                    0.924750
#
#                             demand_rolling_std_24hrs  \
# hour                                        0.006937
# dayofweek                                  -0.038889
# month                                      -0.009308
# year                                       -0.000502
# dayofyear                                  -0.012277
# weekofyear                                 -0.023199
# quarter                                    -0.004329
# is_weekend                                 -0.144232
# Temperature                                 0.568859
# Humidity                                    0.002245
# Demand                                      0.478369
# demand_rolling_mean_24hrs                   0.810988
# demand_rolling_std_24hrs                    1.000000
# demand_rolling_mean_168hrs                  0.712129
# demand_rolling_std_168hrs                   0.745036
#
#                             demand_rolling_mean_168hrs  \
# hour                                          0.000175
# dayofweek                                     0.000021
# month                                         0.096048
# year                                          0.077481
# dayofyear                                     0.092593
# weekofyear                                    0.080718
# quarter                                       0.100711
# is_weekend                                    0.000167
# Temperature                                   0.789095
# Humidity                                      0.108388
# Demand                                        0.600062
# demand_rolling_mean_24hrs                     0.968750
# demand_rolling_std_24hrs                      0.712129
# demand_rolling_mean_168hrs                    1.000000
# demand_rolling_std_168hrs                     0.953265
#
#                             demand_rolling_std_168hrs
# hour                                        -0.000017
# dayofweek                                    0.000317
# month                                        0.032398
# year                                         0.005474
# dayofyear                                    0.027435
# weekofyear                                   0.014178
# quarter                                      0.034645
# is_weekend                                   0.000162
# Temperature                                  0.738544
# Humidity                                     0.042249
# Demand                                       0.572373
# demand_rolling_mean_24hrs                    0.924750
# demand_rolling_std_24hrs                     0.745036
# demand_rolling_mean_168hrs                   0.953265
# demand_rolling_std_168hrs                    1.000000

# %%
# Correlation Matrix and Heatmap
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot = True, fmt=".2f") # anoot=True : to show the numbers , fmt : to adjust decimals
plt.title("Correlation Matrix of Features")
plt.show()

# %%
data
# Out:
#             hour  dayofweek  month    year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-07  23.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-08   0.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   1.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   2.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   3.0        2.0    1.0  2020.0        8.0           2        1
# ...          ...        ...    ...     ...        ...         ...      ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  23.0        1.0   12.0  2024.0      366.0           1        4
#
#             is_weekend  Temperature   Humidity       Demand  \
# Timestamp
# 2020-01-07           0     3.000000  44.708096  2657.653050
# 2020-01-08           0     3.000000  47.891592  2363.060115
# 2020-01-08           0     4.433666  61.209727  2282.558766
# 2020-01-08           0     5.000529  63.868618  2193.324174
# 2020-01-08           0     4.253477  44.603210  2208.724679
# ...                ...          ...        ...          ...
# 2024-12-31           0     3.956838  43.287161  4689.693109
# 2024-12-31           0     3.118824  51.705756  4331.249224
# 2024-12-31           0     3.000000  40.565916  4015.979957
# 2024-12-31           0     3.000000  51.998107  3353.241682
# 2024-12-31           0     6.037472  59.931925  3219.023339
#
#             demand_rolling_mean_24hrs  demand_rolling_std_24hrs  \
# Timestamp
# 2020-01-07                3851.799511               1016.958689
# 2020-01-08                3857.890516               1007.130968
# 2020-01-08                3852.992863               1014.785101
# 2020-01-08                3840.501897               1033.916351
# 2020-01-08                3839.138277               1036.136212
# ...                               ...                       ...
# 2024-12-31                4039.969992                976.961312
# 2024-12-31                4045.945201                978.342615
# 2024-12-31                4052.475170                977.565114
# 2024-12-31                4053.469866                976.809200
# 2024-12-31                4059.664276                970.756385
#
#             demand_rolling_mean_168hrs  demand_rolling_std_168hrs
# Timestamp
# 2020-01-07                 3737.673189                 973.328362
# 2020-01-08                 3737.113310                 974.096125
# 2020-01-08                 3737.188632                 973.982477
# 2020-01-08                 3737.055797                 974.192732
# 2020-01-08                 3737.261108                 973.864974
# ...                                ...                        ...
# 2024-12-31                 3939.391474                 973.246610
# 2024-12-31                 3937.353242                 972.057461
# 2024-12-31                 3938.303367                 972.055830
# 2024-12-31                 3937.924562                 972.272618
# 2024-12-31                 3936.594579                 973.106891
#
# [43677 rows x 15 columns]

# %%
# Defining Target Variable (Y)
Y=data.Demand                # target variable / dependent variable

# %%
# Defining Features (X)
X= data.drop('Demand', axis=1)               # independent variables / features / predictors

# %%
print(Y)
# Out:
# Timestamp
# 2020-01-07    2657.653050
# 2020-01-08    2363.060115
# 2020-01-08    2282.558766
# 2020-01-08    2193.324174
# 2020-01-08    2208.724679
#                  ...
# 2024-12-31    4689.693109
# 2024-12-31    4331.249224
# 2024-12-31    4015.979957
# 2024-12-31    3353.241682
# 2024-12-31    3219.023339
# Name: Demand, Length: 43677, dtype: float64

# %%
# print(X)
X               #Features
# Out:
#             hour  dayofweek  month    year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2020-01-07  23.0        1.0    1.0  2020.0        7.0           2        1
# 2020-01-08   0.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   1.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   2.0        2.0    1.0  2020.0        8.0           2        1
# 2020-01-08   3.0        2.0    1.0  2020.0        8.0           2        1
# ...          ...        ...    ...     ...        ...         ...      ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31
# 2020-01-08               1007.130968                 3737.113310
# 2020-01-08               1014.785101                 3737.188632
# 2020-01-08               1033.916351                 3737.055797
# 2020-01-08               1036.136212                 3737.261108
# ...                              ...                         ...
# 2023-12-31                879.089476                 3904.956829
# 2023-12-31                879.430235                 3903.213620
# 2023-12-31                877.726873                 3903.859586
# 2023-12-31                870.777359                 3904.750278
# 2023-12-31                874.865239                 3904.645413
#
#             demand_rolling_std_168hrs
# Timestamp
# 2020-01-07                 973.328362
# 2020-01-08                 974.096125
# 2020-01-08                 973.982477
# 2020-01-08                 974.192732
# 2020-01-08                 973.864974
# ...                               ...
# 2023-12-31                 990.219481
# 2023-12-31                 990.092487
# 2023-12-31                 989.737091
# 2023-12-31                 989.020744
# 2023-12-31                 989.155561
#
# [34893 rows x 14 columns]

# %%
Y_train = Y.loc[ : '2023-12-31' ]             # taking 80% of data as training data

# %%
Y_train
# Out:
# Timestamp
# 2020-01-07    2657.653050
# 2020-01-08    2363.060115
# 2020-01-08    2282.558766
# 2020-01-08    2193.324174
# 2020-01-08    2208.724679
#                  ...
# 2023-12-31    4185.721624
# 2023-12-31    3829.359810
# 2023-12-31    3416.409325
# 2023-12-31    3188.143951
# 2023-12-31    2631.860751
# Name: Demand, Length: 34893, dtype: float64

# %%
X_test = X.loc[ '2024-01-01' : ]               # taking 20% of data as testing data

# %%
X_test            # 20% of the training features data
# Out:
#             hour  dayofweek  month    year  dayofyear  weekofyear  quarter  \
# Timestamp
# 2024-01-01   0.0        0.0    1.0  2024.0        1.0           1        1
# 2024-01-01   1.0        0.0    1.0  2024.0        1.0           1        1
# 2024-01-01   2.0        0.0    1.0  2024.0        1.0           1        1
# 2024-01-01   3.0        0.0    1.0  2024.0        1.0           1        1
# 2024-01-01   4.0        0.0    1.0  2024.0        1.0           1        1
# ...          ...        ...    ...     ...        ...         ...      ...
# 2024-12-31  19.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  20.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  21.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  22.0        1.0   12.0  2024.0      366.0           1        4
# 2024-12-31  23.0        1.0   12.0  2024.0      366.0           1        4
#
#             is_weekend  Temperature   Humidity  demand_rolling_mean_24hrs  \
# Timestamp
# 2024-01-01           0     3.000000  65.297046                3626.185642
# 2024-01-01           0     3.000000  69.068654                3640.380403
# 2024-01-01           0     3.000000  80.885372                3669.813854
# 2024-01-01           0     7.788675  66.501527                3685.801618
# 2024-01-01           0     6.607828  57.858109                3692.926651
# ...                ...          ...        ...                        ...
# 2024-12-31           0     3.956838  43.287161                4039.969992
# 2024-12-31           0     3.118824  51.705756                4045.945201
# 2024-12-31           0     3.000000  40.565916                4052.475170
# 2024-12-31           0     3.000000  51.998107                4053.469866
# 2024-12-31           0     6.037472  59.931925                4059.664276
#
#             demand_rolling_std_24hrs  demand_rolling_mean_168hrs  \
# Timestamp
# 2024-01-01                856.204515                 3904.458526
# 2024-01-01                836.357296                 3905.946024
# 2024-01-01                776.458065                 3906.795695
# 2024-01-01                749.595470                 3907.589381
# 2024-01-01                738.736316                 3907.571622
# ...                              ...                         ...
# 2024-12-31                976.961312                 3939.391474
# 2024-12-31                978.342615                 3937.353242
# 2024-12-31                977.565114                 3938.303367
# 2024-12-31                976.809200                 3937.924562
# 2024-12-31                970.756385                 3936.594579
#
#             demand_rolling_std_168hrs
# Timestamp
# 2024-01-01                 989.377582
# 2024-01-01                 987.317714
# 2024-01-01                 985.981698
# 2024-01-01                 984.901803
# 2024-01-01                 984.923900
# ...                               ...
# 2024-12-31                 973.246610
# 2024-12-31                 972.057461
# 2024-12-31                 972.055830
# 2024-12-31                 972.272618
# 2024-12-31                 973.106891
#
# [8784 rows x 14 columns]

# %%
Y_test = Y.loc[ '2024-01-01' : ]                       # taking 20% of data as testing data

# %%
Y_test                                                 # 20% of the testing target variable
# Out:
# Timestamp
# 2024-01-01    2720.606072
# 2024-01-01    2669.647167
# 2024-01-01    2435.578924
# 2024-01-01    2641.043699
# 2024-01-01    2687.949643
#                  ...
# 2024-12-31    4689.693109
# 2024-12-31    4331.249224
# 2024-12-31    4015.979957
# 2024-12-31    3353.241682
# 2024-12-31    3219.023339
# Name: Demand, Length: 8784, dtype: float64

# %%
print(X_train.shape)                   
print(Y_train.shape)
# Out:
# (34893, 14)
# (34893,)

# %%
print(X_test.shape)
print(Y_test.shape)
# Out:
# (8784, 14)
# (8784,)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\hp\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\hp\appdata\roaming\python\python313\site-packages (from xgboost) (2.3.1)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.15.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from xgboost import XGBRegressor     # from XGBoost library we are importing XGBRegressor class
# from sklearn library importing two fundamental metrics to evaluate the performance of the model
from sklearn.metrics import mean_squared_error, mean_absolute_error

# from model_selection module of scikit-learn's library, import TimeSeriesSplit class
# TimeSeriesSplit class performs appropriate cross-validation when dealing with time series data
from sklearn.model_selection import TimeSeriesSplit

# %%
# Initialize and train the model

model_xgb = XGBRegressor(n_estimators = 1000,                
                         early_stopping_rounds = 50,
                         learning_rate = 0.01,
                         random_state = 42,
                         objective = 'reg:squarederror' )

# %%
# training the model

model_xgb.fit(X_train, Y_train, eval_set = [(X_train, Y_train), (X_test, Y_test)], verbose = False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# Make predictions

predictions_xgb = model_xgb.predict(X_test)

# %%
# Evaluating the model

rmse_xgb = np.sqrt(mean_squared_error(Y_test, predictions_xgb))

mae_xgb = mean_absolute_error(Y_test, predictions_xgb )

# %%
print('XGBoost RMSE:',  rmse_xgb)
print('XGBoost MAE:' ,  mae_xgb)
# Out:
# XGBoost RMSE: 149.864549993725
# XGBoost MAE: 101.1552705516333

# %%
# Visulaize the Predictions

plt.figure(figsize = (15,6))
plt.plot(Y_test.index, Y_test, label = 'Actual Demand', color = 'Blue')
plt.plot(Y_test.index, predictions_xgb, label = 'Predicted Demand', color = 'Red', linestyle='--')
plt.title('XGBoost Electricity Demand Prediction')
plt.xlabel('Date')
plt.ylabel('Demand')
plt.legend()

plt.show()

# %%
# save the model

import joblib

joblib.dump(model_xgb, 'electicity_xgb_prediction_model.pkl')
# Out:
# ['electicity_xgb_prediction_model.pkl']

# %%
# load and Use:

loaded_model = joblib.load('electicity_xgb_prediction_model.pkl')

# future_predictions = loaded_model.predict(X_future)

# %%
loaded_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)
